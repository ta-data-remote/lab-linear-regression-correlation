# %% [markdown]
# # Linear Regression and Correlation
#
# ## Challenge 1
#
# You are the owner of a big company and you suspect that the younger your employees are, the most likely it is that they don't come to work. In order to prove this hypothesis, you have gathered some data:
#
# | EmployeeID | Age | Absences |
# |--------|-----|------------|
# | 1      | 27  | 15         |
# | 2      | 61  | 6          |
# | 3      | 37  | 10         |
# | 4      | 23  | 18         |
# | 5      | 46  |  9         |
# | 6      | 58  |  7         |
# | 7      | 29  | 14         |
# | 8      | 36  | 11         |
# | 9      | 64  |  5         |
# | 10     | 40  |  8         |
#
# You can find this information in the `data` folder of the present repository.
#
# Import the necessary libraries to complete the lab here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
data = pd.read_csv(r'C:\Users\User\Documents\Github\data\absences.csv')

# %% [markdown]
# #### 1. Plot the scatter chart of `Age` and `Absences`. Comment the result. Do you see any relation between `Age` and `Absences`?

# %%
# your code here
x= data["Age"]
y = data["Absences"]
plt.scatter(x, y, alpha=0.5)
plt.title('Scatter plot Age/Absences')
plt.xlabel('Age')
plt.ylabel('Absences')
plt.show()

# %%
# your comments here:
#yes, a negative correlation.

# %% [markdown]
# #### 2.- Define a function to calculate the slope and intercept of the regression line for two variables. Your are not allowed to use any functions or methods that directly calculate those parameters.

# %%
#your code here
def linear_regression(x, y):     
    N = len(x)
    x_mean = x.mean()
    y_mean = y.mean()

    a = ((x - x_mean) * (y - y_mean)).sum()
    b = ((x - x_mean)**2).sum()
    c = a / b
    
    d = y_mean - (c*x_mean)
  
    reg_line = 'y = {} + {}β'.format(d, round(c, 3))
    
    return (d, c, reg_line)
    
    x = data['Age']
    y = data['Absences']
    linear_regression(x, y)

# %% [markdown]
# #### 3.- Use the function you defined in step 2 to calculate the regression line for `Age` and `Absences`. Plot it and comment your results.

# %%
x= data["Age"]
y = data["Absences"]
plt.figure(figsize=(18,9))
plt.scatter(x, y, alpha=0.5)

plt.plot(x, 21.58738189891063 + -0.2681088337033404*x, c = 'r', linewidth=3, alpha=.5, solid_capstyle='round')
plt.scatter(x=x.mean(), y=y.mean(), s=10**2.5, c='r')

# %%
# your comments here



#it demonstrates a downward slope, the trend is very close to the points in the most cases.

# %% [markdown]
# #### 4.- Define a function to calculate the covariance and the correlation of two variables.

# %%
# your code here

def covariance(x, y):
    mean_x = sum(x)/float(len(x))
    mean_y = sum(y)/float(len(y))
 
    sub_x = [i - mean_x for i in x]
    sub_y = [i - mean_y for i in y]
    numerator = sum([sub_x[i]*sub_y[i] for i in range(len(sub_x))])
    denominator = len(x)-1
    cov = numerator/denominator
    return cov


def correlation(x, y):
    mean_x = sum(x)/float(len(x))
    mean_y = sum(y)/float(len(y))
    sub_x = [i-mean_x for i in x]
    sub_y = [i-mean_y for i in y]
    numerator = sum([sub_x[i]*sub_y[i] for i in range(len(sub_x))])
    std_deviation_x = sum([sub_x[i]**2.0 for i in range(len(sub_x))])
    std_deviation_y = sum([sub_y[i]**2.0 for i in range(len(sub_y))])
    denominator = (std_deviation_x*std_deviation_y)**0.5 
    cor = numerator/denominator
    return cor

# %% [markdown]
# #### 5.- Use the function you defined in step 4 to calculate the covariance and the correlation of `Age` and `Absences`. Compare them and comment.

# %%
# your code here
x = data['Age']
y = data['Absences']
correlation(x, y)
# Out:
# -0.9325434092481012

# %%
covariance(x,y)
# Out:
# -57.699999999999996

# %%
# your comments here
#Negative correlation and covariance. The covariance seems to be higher.

# %% [markdown]
# #### 6.- Summarize your results, interpret them and give some insights. Can you confirm that the age is an indicator of absenteeism?

# %%
# your comments here
#definitely , we can confirm that age has a negative impact on absenteeism.

# %% [markdown]
# ## Challenge 2
#
# Good Ironhackers stay in campus on Fridays for Ironbeers. You suspect that the more people you tell to stay, the most likely it is that they don't. You want to know if you are the reason why people don't stay so you decide to do an analysis.
#
# X is the number of people that you told to stay and Y is the number of people that actually stayed.
#
# | X | Y |
# |---|---|
# | 1 | 1 |
# | 3 | 2 |
# | 4 | 4 |
# | 6 | 4 |
# | 8 | 5 |
# | 9 | 7 |
# | 11 |8 |
# | 14 | 9 |
#
# Use the following command to create a dataframe with the data about Ironbeers attendance:

# %%
ironbeers_df = pd.DataFrame({'X': [1,3,4,6,8,9,11,14], 'Y': [1,2,4,4,5,7,8,9]})

# %% [markdown]
# #### 1.- Calculate the covariance and the correlation of `X` and `Y`. Comment on the results.

# %%
# your code here
ironbeers_df.head()
ironbeers_df["X"].corr(ironbeers_df["Y"])
# Out:
# 0.9770084209183943

# %%
covariance = np.cov(ironbeers_df["X"], ironbeers_df["Y"], ddof=1)[0][1]
covariance
# Out:
# 12.0

# %%
# your comments here
#positive correlation and covariance between X and Y

# %% [markdown]
# #### 2.- Plot the scatter chart of `X` and `Y`. Comment on the results.

# %%
# your code here
x= ironbeers_df["X"]
y = ironbeers_df["Y"]
plt.figure(figsize=(18,8))
plt.scatter(x, y, alpha=0.5)

# %%
# your comments here
#

# %% [markdown]
# #### 3.- Calculate the regression line for `X` and `Y`. Commment on the results.

# %%
# your code here
x= ironbeers_df["X"]
y = ironbeers_df["Y"]
plt.figure(figsize=(18,8))
plt.scatter(x, y, alpha=0.5)
    
plt.plot(x, 0.3 + 0.7*x, c = 'r', linewidth=3, alpha=.5, solid_capstyle='round')

# %% [markdown]
# #### 4.- What is your conclusion? Are you the reason why people is not staying on Fridays?

# %%
# your comments here
#strong positive correlation and has an impact on staying

# %% [markdown]
# ## Bonus Challenge: Error Analysis
#
# You are going to do an analysis to check whether two random variables fit into a linear regression or not.
#
# In this challenge, you are asked to do an error analysis using the data in **challenge 2**. An "error" is the difference between the expected value of an observation (the regression line value) and the actual value.
#
# #### 1.- First create a new column `expected_Y` in `ironbeers_df` to store the expected `Y` value for each `X`.
# **Hint**: You get the expected `Y` by evaluating the regression line for each `X`.

# %%
# your code here

# %%
# Out:
#     X  Y  expected_Y
# 0   1  1    1.181818
# 1   3  2    2.454545
# 2   4  4    3.090909
# 3   6  4    4.363636
# 4   8  5    5.636364
# 5   9  7    6.272727
# 6  11  8    7.545455
# 7  14  9    9.454545

# %%
# Out:
# R2_score: 0.9545454545454548

# %% [markdown]
# #### 2.- Create a new column `error` in `ironbeers_df` to store the error between the actual and expected values of `Y`. Plot the scatter chart of `X` and `error`.

# %%
# your code here

# %%
# Out:
#     X  Y  expected_Y     error
# 0   1  1    1.181818 -0.181818
# 1   3  2    2.454545 -0.454545
# 2   4  4    3.090909  0.909091
# 3   6  4    4.363636 -0.363636
# 4   8  5    5.636364 -0.636364
# 5   9  7    6.272727  0.727273
# 6  11  8    7.545455  0.454545
# 7  14  9    9.454545 -0.454545

# %% [markdown]
# #### 3.- The closer the points to zero, the best the actual values fit the linear regression. Comment the plot above. Do you see any particular points with a high error?

# %%
# comment here

# %% [markdown]
# #### 4.- Remove the points with a high error (0.6 threshold) and recalculate the regression line.

# %%
# your code here
# Out:
#     X  Y  expected_Y     error
# 0   1  1    1.181818 -0.181818
# 1   3  2    2.454545 -0.454545
# 2   6  4    4.363636 -0.363636
# 3   8  5    5.636364 -0.636364
# 4  11  8    7.545455  0.454545
# 5  14  9    9.454545 -0.454545

# %%
# Out:
# Plot before deleting higher error data points:

# %%
# Out:
# Plot after deleting higher error data points:

# %% [markdown]
# #### 5.- Calculate the correlation. What is happening? Comment the result.

# %%
# your code here

# %%
# Out:
# Covariance and correlation before deleting higher error data points:
# (12.0, 0.9770084209183943)

# %%
# Out:
# Covariance and correlation after deleting higher error data points:
# (15.433333333333332, 0.9928560954470167)

# %%
# your comments here
